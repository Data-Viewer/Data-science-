# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/harissriramoju/DataScience-Samples/master/gapminder.tsv",sep='\t')

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info
# Out:
# <bound method DataFrame.info of           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]>

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.tail()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
df.head(20)
# Out:
#         country continent  year  lifeExp       pop    gdpPercap
# 0   Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1   Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2   Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3   Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4   Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5   Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6   Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7   Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8   Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9   Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10  Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11  Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12      Albania    Europe  1952   55.230   1282697  1601.056136
# 13      Albania    Europe  1957   59.280   1476505  1942.284244
# ...

# %%
df.tail(10)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1694  Zimbabwe    Africa  1962   52.358   4277736  527.272182
# 1695  Zimbabwe    Africa  1967   53.995   4995432  569.795071
# 1696  Zimbabwe    Africa  1972   55.635   5861135  799.362176
# 1697  Zimbabwe    Africa  1977   57.674   6642107  685.587682
# 1698  Zimbabwe    Africa  1982   60.363   7636524  788.855041
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
df.sample(10)
# Out:
#                   country continent  year  lifeExp       pop     gdpPercap
# 1096          New Zealand   Oceania  1972   71.890   2929100  16046.037280
# 1151               Norway    Europe  2007   80.196   4627926  49357.190170
# 901                 Libya    Africa  1957   45.289   1201578   3448.284395
# 891               Liberia    Africa  1967   41.536   1279406    713.603648
# 1549  Trinidad and Tobago  Americas  1957   61.800    764900   4100.393400
# 143               Bolivia  Americas  2007   65.554   9119152   3822.137084
# 594                Greece    Europe  1982   75.240   9786480  15268.420890
# 592                Greece    Europe  1972   72.340   8888628  12724.829570
# 1510               Taiwan      Asia  2002   76.990  22454239  23235.423290
# 1548  Trinidad and Tobago  Americas  1952   59.100    662850   3023.271928

# %%
df.shape
# Out:
# (1704, 6)

# %% [markdown]
# ### How to access single column from a Dataaframe

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df[['country','year','lifeExp']]
# Out:
#           country  year  lifeExp
# 0     Afghanistan  1952   28.801
# 1     Afghanistan  1957   30.332
# 2     Afghanistan  1962   31.997
# 3     Afghanistan  1967   34.020
# 4     Afghanistan  1972   36.088
# ...           ...   ...      ...
# 1699     Zimbabwe  1987   62.351
# 1700     Zimbabwe  1992   60.377
# 1701     Zimbabwe  1997   46.809
# 1702     Zimbabwe  2002   39.989
# 1703     Zimbabwe  2007   43.487
#
# [1704 rows x 3 columns]

# %%
type(df[['country','year']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df[['pop','lifeExp']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['pop','lifeExp']].head(10)
# Out:
#         pop  lifeExp
# 0   8425333   28.801
# 1   9240934   30.332
# 2  10267083   31.997
# 3  11537966   34.020
# 4  13079460   36.088
# 5  14880372   38.438
# 6  12881816   39.854
# 7  13867957   40.822
# 8  16317921   41.674
# 9  22227415   41.763

# %%
df[['country','year','lifeExp']].tail(10)
# Out:
#        country  year  lifeExp
# 1694  Zimbabwe  1962   52.358
# 1695  Zimbabwe  1967   53.995
# 1696  Zimbabwe  1972   55.635
# 1697  Zimbabwe  1977   57.674
# 1698  Zimbabwe  1982   60.363
# 1699  Zimbabwe  1987   62.351
# 1700  Zimbabwe  1992   60.377
# 1701  Zimbabwe  1997   46.809
# 1702  Zimbabwe  2002   39.989
# 1703  Zimbabwe  2007   43.487

# %%
df[['country','year','lifeExp']]
# Out:
#           country  year  lifeExp
# 0     Afghanistan  1952   28.801
# 1     Afghanistan  1957   30.332
# 2     Afghanistan  1962   31.997
# 3     Afghanistan  1967   34.020
# 4     Afghanistan  1972   36.088
# ...           ...   ...      ...
# 1699     Zimbabwe  1987   62.351
# 1700     Zimbabwe  1992   60.377
# 1701     Zimbabwe  1997   46.809
# 1702     Zimbabwe  2002   39.989
# 1703     Zimbabwe  2007   43.487
#
# [1704 rows x 3 columns]

# %%
df['continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %% [markdown]
# ### df.head()

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %% [markdown]
# ### loc(only Row and column names) & iloc(only inexes names)

# %%
df.loc[0,:]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
df.loc[[0,9,99,999],'country']
# Out:
# 0      Afghanistan
# 9      Afghanistan
# 99      Bangladesh
# 999       Mongolia
# Name: country, dtype: object

# %%
df.loc[[0,99,999],['country','year','lifeExp']]
# Out:
#          country  year  lifeExp
# 0    Afghanistan  1952   28.801
# 99    Bangladesh  1967   43.453
# 999     Mongolia  1967   51.253

# %%
df.loc[40:50,'country':'pop']
# Out:
#       country continent  year  lifeExp       pop
# 40     Angola    Africa  1972   37.928   5894858
# 41     Angola    Africa  1977   39.483   6162675
# 42     Angola    Africa  1982   39.942   7016384
# 43     Angola    Africa  1987   39.906   7874230
# 44     Angola    Africa  1992   40.647   8735988
# 45     Angola    Africa  1997   40.963   9875024
# 46     Angola    Africa  2002   41.003  10866106
# 47     Angola    Africa  2007   42.731  12420476
# 48  Argentina  Americas  1952   62.485  17876956
# 49  Argentina  Americas  1957   64.399  19610538
# 50  Argentina  Americas  1962   65.142  21283783

# %%
df.loc[10:25,'continent':'pop']
# Out:
#    continent  year  lifeExp       pop
# 10      Asia  2002   42.129  25268405
# 11      Asia  2007   43.828  31889923
# 12    Europe  1952   55.230   1282697
# 13    Europe  1957   59.280   1476505
# 14    Europe  1962   64.820   1728137
# 15    Europe  1967   66.220   1984060
# 16    Europe  1972   67.690   2263554
# 17    Europe  1977   68.930   2509048
# 18    Europe  1982   70.420   2780097
# 19    Europe  1987   72.000   3075321
# 20    Europe  1992   71.581   3326498
# 21    Europe  1997   72.950   3428038
# 22    Europe  2002   75.651   3508512
# 23    Europe  2007   76.423   3600523
# 24    Africa  1952   43.077   9279525
# 25    Africa  1957   45.685  10270856

# %%
df['country'].unique() # to find unique countries from the df
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
df[:10]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6  Afghanistan      Asia  1982   39.854  12881816  978.011439
# 7  Afghanistan      Asia  1987   40.822  13867957  852.395945
# 8  Afghanistan      Asia  1992   41.674  16317921  649.341395
# 9  Afghanistan      Asia  1997   41.763  22227415  635.341351

# %%
df[1:20]
# Out:
#         country continent  year  lifeExp       pop    gdpPercap
# 1   Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2   Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3   Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4   Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5   Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6   Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7   Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8   Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9   Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10  Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11  Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12      Albania    Europe  1952   55.230   1282697  1601.056136
# 13      Albania    Europe  1957   59.280   1476505  1942.284244
# 14      Albania    Europe  1962   64.820   1728137  2312.888958
# ...

# %%
df[:2]
# Out:
#        country continent  year  lifeExp      pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801  8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332  9240934  820.853030

# %%
df.continent # to find the continent column from the df
# Out:
# 0         Asia
# 1         Asia
# 2         Asia
# 3         Asia
# 4         Asia
#          ...
# 1699    Africa
# 1700    Africa
# 1701    Africa
# 1702    Africa
# 1703    Africa
# Name: continent, Length: 1704, dtype: object

# %%
len(df['country'].unique()) # to find len of unique countries from the df
# Out:
# 142

# %%
df['continent'].unique() # to find unique continents in the df
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %%
df.loc[[0,3,5],["country","pop"]] # by using loc method we take rows & columns in the df
# Out:
#        country       pop
# 0  Afghanistan   8425333
# 3  Afghanistan  11537966
# 5  Afghanistan  14880372

# %%
df.loc[2:10,'country'] # by using loc method
# Out:
# 2     Afghanistan
# 3     Afghanistan
# 4     Afghanistan
# 5     Afghanistan
# 6     Afghanistan
# 7     Afghanistan
# 8     Afghanistan
# 9     Afghanistan
# 10    Afghanistan
# Name: country, dtype: object

# %%
df.iloc[0:10,[0,1,2,3]]
# Out:
#        country continent  year  lifeExp
# 0  Afghanistan      Asia  1952   28.801
# 1  Afghanistan      Asia  1957   30.332
# 2  Afghanistan      Asia  1962   31.997
# 3  Afghanistan      Asia  1967   34.020
# 4  Afghanistan      Asia  1972   36.088
# 5  Afghanistan      Asia  1977   38.438
# 6  Afghanistan      Asia  1982   39.854
# 7  Afghanistan      Asia  1987   40.822
# 8  Afghanistan      Asia  1992   41.674
# 9  Afghanistan      Asia  1997   41.763
